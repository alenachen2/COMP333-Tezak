# %%
import cv2
import os
import numpy as np
import matplotlib.pyplot as plt
import cellpose
from cellpose import models
from cellpose import io
from cellpose.io import imread
from cellpose import plot
from file_retrieval import get_file_path

# %%
#Retrieve image path
img_path = get_file_path()

#Read image
img_bgr = cv2.imread(img_path)
#Convert BGR to RGB so it displays correctly
img = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)

#Create Cellpose model
model = models.CellposeModel(gpu=True)

#Segment image
masks, flows, styles = model.eval(
    img,
    flow_threshold=0.4, 
    cellprob_threshold=0.0,   # grayscale
)

#Display results
fig = plt.figure(figsize=(12,5))
plot.show_segmentation(fig, img, masks, flows[0])
plt.tight_layout()
plt.show()
# Out:
# [ WARN:0@4.525] global loadsave.cpp:275 findDecoder imread_(''): can't open/read file: check file path/integrity
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[3], line 7
#       5 img_bgr = cv2.imread(img_path)
#       6 #Convert BGR to RGB so it displays correctly
# ----> 7 img = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
#       9 #Create Cellpose model
#      10 model = models.CellposeModel(gpu=True)
#
# error: OpenCV(4.12.0) /Users/xperience/GHA-Actions-OpenCV/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
